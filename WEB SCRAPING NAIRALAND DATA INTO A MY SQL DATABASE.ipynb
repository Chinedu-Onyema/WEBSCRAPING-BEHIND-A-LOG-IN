# %%
# I could just scrap the website directly if it not behind a log in
# But i couldn't because it is behind a log in


from bs4 import BeautifulSoup
import requests
url = 'https://www.nairaland.com/jobs'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en-US"><head><title>Just a moment...</title><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="IE=Edge" http-equiv="X-UA-Compatible"/><meta content="noindex,nofollow" name="robots"/><meta content="width=device-width,initial-scale=1" name="viewport"/><style>*{box-sizing:border-box;margin:0;padding:0}html{line-height:1.15;-webkit-text-size-adjust:100%;color:#313131;font-family:system-ui,-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,Noto Color Emoji}body{display:flex;flex-direction:column;height:100vh;min-height:100vh}.main-content{margin:8rem auto;max-width:60rem;padding-left:1.5rem}@media (width <= 720px){.main-content{margin-top:4rem}}.h2{font-size:1.5rem;font-weight:500;line-height:2.25rem}@media (width <= 720px){.h2{font-size:1.25rem;line-height:1.5rem}}#challenge-error-text{background-image:url(data:image/svg+xml;base64,...);background-repeat:no-repeat;background-size:contain;padding-left:34px}@media (prefers-color-scheme:dark){body{background-color:#222;color:#d9d9d9}}</style><meta content="390" http-equiv="refresh"/></head><body class="no-js"><div class="main-wrapper" role="main"><div class="main-content"><noscript><div class="h2"><span id="challenge-error-text">Enable JavaScript and cookies to continue</span></div></noscript></div></div><script>(function(){window._cf_chl_opt={cvId: '3',cZone: "www.nairaland.com",cType: 'managed',cNounce: '96371',cRay: '8cc82bd879ebb969',cHash: '459cb4218684b95',cUPMDTk: "\/jobs?__cf_chl_tk=3JxVOTcfcOVS5VDBq2OOHSpwsWniFNdk._lAP19Ah_U-1727908586-0.0.1.1-4436",cFPWv: 'g',cTTimeMs: '1000',cMTimeMs: '390000',cTplV: 5,cTplB: 'cf',cK: "",fa: "\/jobs?__cf_chl_f_tk=3JxVOTcfcOVS5VDBq2OOHSpwsWniFNdk._lAP19Ah_U-1727908586-0.0.1.1-4436",md: "zLA1JheaHMsrOa2tsmbgxM2hambLU7p2ALHzcCphXmM-1727908586-1.1.1.1-1tLkj5j3wfWkIpiMerlMwxle1hK7IS65zdTK6iADI.52IvDjZWyxflfy3wiwR.dcV3sJijyrWTU2OkTsnl3PjTupH7qn219BpdlAOTA6N5o167doloaWg98p.wTArv7LX6dd1nWUb8pB0c5oh_eACafk7qa0ANpIAVEYIznlN60uhavjYpRVEfwoWxY7KBlyteR2OCSjxHm7_L0N5FXigkLF.u.08.2yGGFy_Lnxg0U0QJn_dBZxqr4aieTIshMa8F_tP84s0gTVYw.Gc2LWGxFjaymWS.rko8zNjDLD5PSSzYD11noyo7nXF1_1.0hVIX7nj0RNA.sfVH8vlfDDdXV8nX2Xt9IGOCt7VQJBOzXrWNluGGIGtkhJlg4OWG6IwXwPsoMSBOdpEWE
# %%
# when my data is behind a log in, i could use the cookies
# and headers from the website by copying the cURL as bash
# from the network category in the developer tools and pasting
# it in https://curlconverter.com/ which organiises the cookies and headers of the website
# in a dictionary and then i can import the beautiful soup and request libraries.


import requests
from bs4 import BeautifulSoup

cookies = {
    'ai_user': 'e2Hi55QF1yZg+yBbxztwp6|2024-09-23T04:04:09.869Z',
    'session': '""',
    '_gid': 'GA1.2.927634570.1727849250',
    '__gads': 'ID=b82f70ee813806ec:T=1727064691:RT=1727849696:S=ALNI_MbX4hXYSDlvWE9FqwH08BS8-VgnMA',
    '__gpi': 'UID=00000f096ea6a392:T=1727064691:RT=1727849696:S=ALNI_MYDy964LQKQu4a5evvNhU6RiNAV6w',
    '__eoi': 'ID=9c42286dda43baf5:T=1727064691:RT=1727849696:S=AA-AfjYpPn8xZaYyKA3TAmN8o-44',
    'FCNEC': '%5B%5B%22AKsRol9TcnUvFlUTk2YxxAWVCmcIdyFo_sk4-wyu9PdZa4HUZtqNoi-f4sc1glHbztVAD8XFdexFjlGlK39rbbVbSLzLutPd8qgsNjWLkGFi_iULFKPA3j5OfMMBi-KxR-Lz51PBU415C5_AvZ84EaKE5aGuz_OodQ%3D%3D%22%5D%5D',
    '_ga_GGM2XGB2C1': 'GS1.1.1727849249.3.1.1727849305.0.0.0',
    '_ga': 'GA1.1.117970615.1727064250',
}

headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'en-US,en;q=0.9',
    'cache-control': 'max-age=0',
    # 'cookie': 'ai_user=e2Hi55QF1yZg+yBbxztwp6|2024-09-23T04:04:09.869Z; session=""; _gid=GA1.2.927634570.1727849250; __gads=ID=b82f70ee813806ec:T=1727064691:RT=1727849696:S=ALNI_MbX4hXYSDlvWE9FqwH08BS8-VgnMA; __gpi=UID=00000f096ea6a392:T=1727064691:RT=1727849696:S=ALNI_MYDy964LQKQu4a5evvNhU6RiNAV6w; __eoi=ID=9c42286dda43baf5:T=1727064691:RT=1727849696:S=AA-AfjYpPn8xZaYyKA3TAmN8o-44; FCNEC=%5B%5B%22AKsRol9TcnUvFlUTk2YxxAWVCmcIdyFo_sk4-wyu9PdZa4HUZtqNoi-f4sc1glHbztVAD8XFdexFjlGlK39rbbVbSLzLutPd8qgsNjWLkGFi_iULFKPA3j5OfMMBi-KxR-Lz51PBU415C5_AvZ84EaKE5aGuz_OodQ%3D%3D%22%5D%5D; _ga_GGM2XGB2C1=GS1.1.1727849249.3.1.1727849305.0.0.0; _ga=GA1.1.117970615.1727064250',
    'priority': 'u=0, i',
    'referer': 'https://www.nairaland.com/',
    'sec-ch-ua': '"Google Chrome";v="129", "Not=A?Brand";v="8", "Chromium";v="129"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36',
}

response = requests.get('https://www.nairaland.com/jobs', cookies=cookies, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN"
# "http://www.w3.org/TR/html4/loose.dtd">
# <html><head><title>Jobs/Vacancies - Nigeria - Nairaland</title><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><link href="https://www.nairaland.com/static/nl2.css/6399077938932" rel="stylesheet" type="text/css"/><meta content="KUABan1rWBhK3Jb2LePxHAv00FEbbM1wQMAAgsN-EyA" name="google-site-verification"/><link href="https://fonts.gstatic.com" rel="preconnect"/><link href="https://fonts.googleapis.com/css2?family=Open+Sans:ital,wght@0,400;0,700;1,400;1,700&amp;display=swap" rel="stylesheet"/></head><body><div class="body"><table id="up" summary=""><tr><td class="grad"><h1><a class="g" href="https://www.nairaland.com/" title="Nairaland, the Nigerian Forum"><img height="24" src="/static/logo1.png" width="246"/></a></h1> Welcome, <b>Guest</b>: <b><a href="/register">Register On Nairaland</a></b> / <a href="/login">LOGIN!</a> / <a href="/trending">Trending</a> / <a href="/recent">Recent</a> / <a href="/topics">New</a><br/><b>Stats: </b>3,197,467 members, 7,964,901 topics. <b>Date</b>: Thursday, 03 October 2024 at 12:39 AM<p><form action="/search"> <input name="q" size="32" type="text"/>
# <input name="search" type="submit" value="Search"/></form> </p></td></tr></table><a name="top"></a><h2>Jobs/Vacancies - Nairaland</h2><p class="bold"><a href="/">Nairaland Forum</a> / <a href="/nairaland">Nairaland / General</a> / <a href="/jobs">Jobs/Vacancies</a> <p><a href="/jobs">Jobs/Vacancies</a>: Job/Employment Opportunities; Vacancies In Nigeria! <b>Ad Rate</b>: <a href="/adrates">₦<b>3,935.59</b>/week (<b>35.2</b>% discount)</a>.<br/><div class="vertipics"><a href="/hopto/jobs/16257" rel="sponsored" target="_blank"><img src="https://www.nairaland.com/vertipics/8xfesnbwut894gm6gm3rdb2gefu3h8nm.jpg"/></a><a href="/hopto/jobs/111" rel="sponsored" target="_blank"><img src="https://www.nairaland.com/vertipics/ujsti16vmkvlxuxyzafqz3hlbs1j0np6.png"/></a><a href="/hopto/jobs/18399" rel="sponsored" target="_blank"><img src="https://www.nairaland.com/vertipics/i9r91xlzwdp0wn5fnizu9l3tbjs29lgm.png"/></a></div><p> <b>(1)</b> <a href="https://www.nairaland.com/jobs/1">(2)</a> <a href="https://www.nairaland.com/jobs/2">(3)</a> <a href="https://www.nairaland.com/jobs/3">(4)</a> <a href="https://www.nairaland.com/jobs/4">(5)</a> <a href="https://www.nairaland.com/jobs/5">(6)</a> <a href="https://www.nairaland.com/jobs/6">(7)</a> <a href="https://www.nairaland.com/jobs/7">(8)</a> <a href="https://www.nairaland.com/jobs/8">(9)</a> <a href="https://www.nairaland.com/jobs/9">(10)</a>  (of <b>6368</b> p
el">travel</a> <a href="/sports">sports</a> <a href="/fashion">fashion</a> <a href="/health">health</a> <br/> <a href="/religion">religion</a> <a href="/celebs">celebs</a> <a href="/tv-movies">tv-movies</a> <a href="/music-radio">music-radio</a> <a href="/literature">literature</a> <a href="/webmasters">webmasters</a> <a href="/programming">programming</a> <a href="/techmarket">techmarket</a> <p>Links:  <a href="/news" title="Page 1, Nairaland News ">(1)</a> <a href="/news/1" title="Page 2, Nairaland News ">(2)</a> <a href="/news/2" title="Page 3, Nairaland News ">(3)</a> <a href="/news/3" title="Page 4, Nairaland News ">(4)</a> <a href="/news/4" title="Page 5, Nairaland News ">(5)</a> <a href="/news/5" title="Page 6, Nairaland News ">(6)</a> <a href="/news/6" title="Page 7, Nairaland News ">(7)</a> <a href="/news/7" title="Page 8, Nairaland News ">(8)</a> <a href="/news/8" title="Page 9, Nairaland News ">(9)</a> <a href="/news/9" title="Page 10, Nairaland News ">(10)</a> <p><b><a href="/" title="Nigerian Forum">Nairaland</a></b> - Copyright © 2005 - 2024 <a href="http://www.seunosewa.com" title="Seun">Oluwaseun Osewa</a>. All rights reserved. See <a href="https://www.nairaland.com/1049481/how-place-targeted-ads-nairaland">How To Advertise</a>. 6<br/><b>Disclaimer</b>: Every Nairaland member is <b>solely responsible</b> for <b>anything</b> that he/she <b>posts</b> or <b>uploads</b> on Nairaland.</p></p></p></td></tr></table></p></p></p></p></p></p></p></p></div><!-- Google tag (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-91638-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-91638-1');
# </script>
# <script src="https://www.nairaland.com/static/nl2.js/5422354354" type="text/javascript"></script></body></html>

# %%
# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Extract the main poster's name
poster_name_tag = soup.find('a', href='/laurelp')
poster_name = poster_name_tag.text if poster_name_tag else 'N/A'

# Extract the number of posts and views
post_views_info = soup.find('span', class_='s')
posts_and_views = post_views_info.find_all('b')
post_count = posts_and_views[1].text if len(posts_and_views) > 1 else 'N/A'
views = posts_and_views[2].text if len(posts_and_views) > 2 else 'N/A'

# Extract the time and date of the post
time = post_views_info.find_all('b')[3].text if len(posts_and_views) > 3 else 'N/A'
date = post_views_info.find_all('b')[4].text if len(posts_and_views) > 4 else 'N/A'

# Extract the second poster's name (last poster)
last_poster_tag_name = soup.find('a', href= '/seundy')  # Get the last poster from the <a> tag list
last_poster = last_poster_tag_name.text if last_poster_tag_name else 'N/A'

# Print the extracted data
print(f"Poster Name: {poster_name}")
print(f"Post Count: {post_count}")
print(f"Views: {views}")
print(f"Time: {time}")
print(f"Date: {date}")
print(f"Last Poster Name: {last_poster}")
# Out:
# Poster Name: LaurelP
# Post Count: 8633
# Views: 1864683
# Time: 3:09pm
# Date: Oct 02
# Last Poster Name: seundy

# %%
# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find all post blocks (adjust the tag and class according to actual structure)
posts = soup.find_all('span', class_='s')  # Assuming each post details are within <span> with class 's'

# Initialize lists to store the extracted information
poster_names = []
post_counts = []
view_counts = []
times = []
dates = []
last_posters = []

# Loop through each post block to extract information
for post_views_info in posts:
    # Extract poster's name
    poster_name_tag = post_views_info.find('a')  # Assuming the first <a> tag is the poster's name
    poster_name = poster_name_tag.text if poster_name_tag else 'N/A'
    poster_names.append(poster_name)

    # Extract the number of posts and views
    posts_and_views = post_views_info.find_all('b')
    post_count = posts_and_views[1].text if len(posts_and_views) > 1 else 'N/A'
    post_counts.append(post_count)

    view_count = posts_and_views[2].text if len(posts_and_views) > 2 else 'N/A'
    view_counts.append(view_count)

    # Extract the time and date of the post
    time = posts_and_views[3].text if len(posts_and_views) > 3 else 'N/A'
    times.append(time)

    date = posts_and_views[4].text if len(posts_and_views) > 4 else 'N/A'
    dates.append(date)

    # Extract the second poster's name (last poster)
    last_poster_tag = post_views_info.find_all('a')[-1]  # Assuming the last <a> tag is the last poster's name
    last_poster = last_poster_tag.text if last_poster_tag else 'N/A'
    last_posters.append(last_poster)

# Display extracted information
for i in range(len(poster_names)):
    print(f"Poster Name: {poster_names[i]}")
    print(f"Post Count: {post_counts[i]}")
    print(f"Views: {view_counts[i]}")
    print(f"Time: {times[i]}")
    print(f"Date: {dates[i]}")
    print(f"Last Poster Name: {last_posters[i]}")
    print('-' * 50)
# Out:
# Poster Name: LaurelP
# Post Count: 8633
# Views: 1864683
# Time: 3:09pm
# Date: Oct 02
# Last Poster Name: seundy
# --------------------------------------------------
# Poster Name: Curdlebug
# Post Count: 6368
# Views: 376405
# Time: 9:43am
# Date: Oct 02
# Last Poster Name: dharmie13
# --------------------------------------------------
# Poster Name: backT
# Post Count: 529
# Views: 136053
# Time: 4:45pm
# Date: Oct 01
# Last Poster Name: Joseph1505
# --------------------------------------------------
# Poster Name: PrettyAmazon
# Post Count: 6
# Views: 657
# Time: 12:19am
# Date: Zayaki
# Last Poster Name: Zayaki
# --------------------------------------------------
# Poster Name: PrettyAmazon
# Post Count: 144
# Views: 5872
# Time: 12:06am
# Date: Thekingsimon
# Last Poster Name: Thekingsimon
# --------------------------------------------------
# Poster Name: PrettyAmazon
# Post Count: 4
# Views: 308
# Time: 11:52pm
# Date: Oct 02
# Last Poster Name: Danfan
# --------------------------------------------------
# Poster Name: Tosade01
# Post Count: 1
# Views: 16
# Time: 11:37pm
# Date: Oct 02
# Last Poster Name: Tosade01
# --------------------------------------------------
# Poster Name: Tohsynetita1
# Post Count: 1
# Views: 29
# Time: 11:20pm
# Date: Oct 02
# Last Poster Name: Tohsynetita1
# --------------------------------------------------
# Poster Name: Qwinjenna
# Post Count: 2
# Views: 397
# Time: 11:17pm
# Date: Oct 02
# Last Poster Name: mrjojo
# --------------------------------------------------
# Poster Name: bisiofgod
# Post Count: 76342
# Views: 6828479
# Time: 11:16pm
# Date: Oct 02
# Last Poster Name: elaino
# --------------------------------------------------
# Poster Name: Anasko
# Post Count: 6
# Views: 1579
# Time: 11:05pm
# Date: Oct 02
# Last Poster Name: 042reports
# --------------------------------------------------
    'FCNEC': '%5B%5B%22AKsRol9TcnUvFlUTk2YxxAWVCmcIdyFo_sk4-wyu9PdZa4HUZtqNoi-f4sc1glHbztVAD8XFdexFjlGlK39rbbVbSLzLutPd8qgsNjWLkGFi_iULFKPA3j5OfMMBi-KxR-Lz51PBU415C5_AvZ84EaKE5aGuz_OodQ%3D%3D%22%5D%5D',
    '_gat_gtag_UA_91638_1': '1',
    '_ga_GGM2XGB2C1': 'GS1.1.1727856871.4.1.1727858023.0.0.0',
    '_ga': 'GA1.1.117970615.1727064250',
}

headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'en-US,en;q=0.9',
    'cache-control': 'max-age=0',
    # 'cookie': 'session=""; ai_user=e2Hi55QF1yZg+yBbxztwp6|2024-09-23T04:04:09.869Z; session=""; _gid=GA1.2.927634570.1727849250; __gads=ID=b82f70ee813806ec:T=1727064691:RT=1727849696:S=ALNI_MbX4hXYSDlvWE9FqwH08BS8-VgnMA; __gpi=UID=00000f096ea6a392:T=1727064691:RT=1727849696:S=ALNI_MYDy964LQKQu4a5evvNhU6RiNAV6w; __eoi=ID=9c42286dda43baf5:T=1727064691:RT=1727849696:S=AA-AfjYpPn8xZaYyKA3TAmN8o-44; FCNEC=%5B%5B%22AKsRol9TcnUvFlUTk2YxxAWVCmcIdyFo_sk4-wyu9PdZa4HUZtqNoi-f4sc1glHbztVAD8XFdexFjlGlK39rbbVbSLzLutPd8qgsNjWLkGFi_iULFKPA3j5OfMMBi-KxR-Lz51PBU415C5_AvZ84EaKE5aGuz_OodQ%3D%3D%22%5D%5D; _gat_gtag_UA_91638_1=1; _ga_GGM2XGB2C1=GS1.1.1727856871.4.1.1727858023.0.0.0; _ga=GA1.1.117970615.1727064250',
    'priority': 'u=0, i',
    'referer': 'https://www.nairaland.com/jobs',
    'sec-ch-ua': '"Google Chrome";v="129", "Not=A?Brand";v="8", "Chromium";v="129"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36',
}

response = requests.get('https://www.nairaland.com/jobs/1', cookies=cookies, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN"
# "http://www.w3.org/TR/html4/loose.dtd">
# <html><head><title>Jobs/Vacancies (2) - Nigeria - Nairaland</title><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><link href="https://www.nairaland.com/static/nl2.css/6399077938932" rel="stylesheet" type="text/css"/><meta content="KUABan1rWBhK3Jb2LePxHAv00FEbbM1wQMAAgsN-EyA" name="google-site-verification"/><link href="https://fonts.gstatic.com" rel="preconnect"/><link href="https://fonts.googleapis.com/css2?family=Open+Sans:ital,wght@0,400;0,700;1,400;1,700&amp;display=swap" rel="stylesheet"/></head><body><div class="body"><table id="up" summary=""><tr><td class="grad"><h1><a class="g" href="https://www.nairaland.com/" title="Nairaland, the Nigerian Forum"><img height="24" src="/static/logo
- 2024 <a href="http://www.seunosewa.com" title="Seun">Oluwaseun Osewa</a>. All rights reserved. See <a href="https://www.nairaland.com/1049481/how-place-targeted-ads-nairaland">How To Advertise</a>. 14<br/><b>Disclaimer</b>: Every Nairaland member is <b>solely responsible</b> for <b>anything</b> that he/she <b>posts</b> or <b>uploads</b> on Nairaland.</p></p></p></td></tr></table></p></p></p></p></p></p></p></p></div><!-- Google tag (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-91638-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-91638-1');
# </script>
# <script src="https://www.nairaland.com/static/nl2.js/5422354354" type="text/javascript"></script></body></html>

# %%
# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Extract the main poster's name
poster_name_tag = soup.find('a', href='/curdlebug')
poster_name = poster_name_tag.text if poster_name_tag else 'N/A'

# Extract the number of posts and views
post_views_info = soup.find('span', class_='s')
posts_and_views = post_views_info.find_all('b')
post_count = posts_and_views[1].text if len(posts_and_views) > 1 else 'N/A'
views = posts_and_views[2].text if len(posts_and_views) > 2 else 'N/A'

# Extract the time and date of the post
time = post_views_info.find_all('b')[3].text if len(posts_and_views) > 3 else 'N/A'
date = post_views_info.find_all('b')[4].text if len(posts_and_views) > 4 else 'N/A'

# Extract the second poster's name (last poster)
last_poster_tag_name = soup.find('a', href= '/dharmie13')  # Get the last poster from the <a> tag list
last_poster = last_poster_tag_name.text if last_poster_tag_name else 'N/A'

# Print the extracted data
print(f"Poster Name: {poster_name}")
print(f"Post Count: {post_count}")
print(f"Views: {views}")
print(f"Time: {time}")
#print(f"Date: {date}")
print(f"Last Poster Name: {last_poster}")
# Out:
# Poster Name: Curdlebug
# Post Count: 6368
# Views: 376405
# Time: 9:43am
# Last Poster Name: dharmie13

# %%
# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find all post blocks (adjust the tag and class according to actual structure)
posts = soup.find_all('span', class_='s')  # Assuming each post details are within <span> with class 's'

# Initialize lists to store the extracted information
poster_names = []
post_counts = []
view_counts = []
times = []
dates = []
last_posters = []

# Loop through each post block to extract information
for post_views_info in posts:
    # Extract poster's name
    poster_name_tag = post_views_info.find('a')  # Assuming the first <a> tag is the poster's name
    poster_name = poster_name_tag.text if poster_name_tag else 'N/A'
    poster_names.append(poster_name)

    # Extract the number of posts and views
    posts_and_views = post_views_info.find_all('b')
    post_count = posts_and_views[1].text if len(posts_and_views) > 1 else 'N/A'
    post_counts.append(post_count)

    view_count = posts_and_views[2].text if len(posts_and_views) > 2 else 'N/A'
    view_counts.append(view_count)

    # Extract the time and date of the post
    time = posts_and_views[3].text if len(posts_and_views) > 3 else 'N/A'
    times.append(time)

    date = posts_and_views[4].text if len(posts_and_views) > 4 else 'N/A'
    dates.append(date)

    # Extract the second poster's name (last poster)
    last_poster_tag = post_views_info.find_all('a')[-1]  # Assuming the last <a> tag is the last poster's name
    last_poster = last_poster_tag.text if last_poster_tag else 'N/A'
    last_posters.append(last_poster)

# Display extracted information
for i in range(len(poster_names)):
# Post Count: 2
# Views: 221
# Time: 8:08am
# Date: Oct 01
# Last Poster Name: PrettyAmazon
# --------------------------------------------------
# Poster Name: PrettyAmazon
# Post Count: 6
# Views: 1264
# Time: 8:05am
# Date: Oct 01
# Last Poster Name: Carohot
# --------------------------------------------------
# Poster Name: Cjay18
# Post Count: 8
# Views: 269
# Time: 7:49am
# Date: Oct 01
# Last Poster Name: Legendguy
# --------------------------------------------------

# %%
# connecting to mySQL Database 
import mysql.connector

mydatabase = mysql.connector.connect(
  host="localhost", # database host
  user="root", # username
  password="****", # password
  port = "3306",
)

print(mydatabase)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x0000021370D60AD0>

# %%
#creating the database w3_schools
mycursor = mydatabase.cursor() # SQL database connector

mycursor.execute("CREATE DATABASE Nairaland_Jobs")

# %%
# showing all the databases in MySQL
mycursor = mydatabase.cursor()
mycursor.execute("SHOW DATABASES")

for x in mycursor:
  print(x)
# Out:
# ('ali_express',)
# ('information_schema',)
# ('mentorship',)
# ('mysql',)
# ('nairaland',)
# ('nairaland_jobs',)
# ('performance_schema',)
# ('project',)
# ('sakila',)
# ('sys',)
# ('w3_schools',)
# ('walmart_sales_data',)
# ('world',)

# %%
# Try connecting to the database "nairaland jobs":
mydatabase = mysql.connector.connect(  
  host="localhost",
  user="root",
  password="****",
  port = "3306",
  database="nairaland_jobs"                                 
)

# %%
mycursor = mydatabase.cursor()

# Corrected CREATE TABLE statement
mycursor.execute("""
    CREATE TABLE Jobs (
    id INT AUTO_INCREMENT PRIMARY KEY, 
    poster_name VARCHAR(255),
    post_count INT,
    view_count VARCHAR(225),
    time_posted VARCHAR(50),
    date_posted VARCHAR(50),
    last_poster_name VARCHAR(255)
    )
""")

# %%
mycursor = mydatabase.cursor()
mycursor.execute("SHOW TABLES")

for x in mycursor:
  print(x)
# Out:
# ('jobs',)

# %%
# PYTHON SCRIPTS PIPELINE FOR THE FIRST TABLE (1) JOBS

import mysql.connector
import requests


cookies = {
    'ai_user': 'e2Hi55QF1yZg+yBbxztwp6|2024-09-23T04:04:09.869Z',
    'session': '""',
    '_gid': 'GA1.2.927634570.1727849250',
    '__gads': 'ID=b82f70ee813806ec:T=1727064691:RT=1727849696:S=ALNI_MbX4hXYSDlvWE9FqwH08BS8-VgnMA',
    '__gpi': 'UID=00000f096ea6a392:T=1727064691:RT=1727849696:S=ALNI_MYDy964LQKQu4a5evvNhU6RiNAV6w',
    '__eoi': 'ID=9c42286dda43baf5:T=1727064691:RT=1727849696:S=AA-AfjYpPn8xZaYyKA3TAmN8o-44',
    'FCNEC': '%5B%5B%22AKsRol9TcnUvFlUTk2YxxAWVCmcIdyFo_sk4-wyu9PdZa4HUZtqNoi-f4sc1glHbztVAD8XFdexFjlGlK39rbbVbSLzLutPd8qgsNjWLkGFi_iULFKPA3j5OfMMBi-KxR-Lz51PBU415C5_AvZ84EaKE5aGuz_OodQ%3D%3D%22%5D%5D',
    '_ga_GGM2XGB2C1': 'GS1.1.1727849249.3.1.1727849305.0.0.0',
    '_ga': 'GA1.1.117970615.1727064250',
}

headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'en-US,en;q=0.9',
    'cache-control': 'max-age=0',
    # 'cookie': 'ai_user=e2Hi55QF1yZg+yBbxztwp6|2024-09-23T04:04:09.869Z; session=""; _gid=GA1.2.927634570.1727849250; __gads=ID=b82f70ee813806ec:T=1727064691:RT=1727849696:S=ALNI_MbX4hXYSDlvWE9FqwH08BS8-VgnMA; __gpi=UID=00000f096ea6a392:T=1727064691:RT=1727849696:S=ALNI_MYDy964LQKQu4a5evvNhU6RiNAV6w; __eoi=ID=9c42286dda43baf5:T=1727064691:RT=1727849696:S=AA-AfjYpPn8xZaYyKA3TAmN8o-44; FCNEC=%5B%5B%22AKsRol9TcnUvFlUTk2YxxAWVCmcIdyFo_sk4-wyu9PdZa4HUZtqNoi-f4sc1glHbztVAD8XFdexFjlGlK39rbbVbSLzLutPd8qgsNjWLkGFi_iULFKPA3j5OfMMBi-KxR-Lz51PBU415C5_AvZ84EaKE5aGuz_OodQ%3D%3D%22%5D%5D; _ga_GGM2XGB2C1=GS1.1.1727849249.3.1.1727849305.0.0.0; _ga=GA1.1.117970615.1727064250',
    'priority': 'u=0, i',
    'referer': 'https://www.nairaland.com/',
    'sec-ch-ua': '"Google Chrome";v="129", "Not=A?Brand";v="8", "Chromium";v="129"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36',
}

# MySQL connection setup
def connect_to_db():
    mydatabase = mysql.connector.connect(  
      host="localhost",
      user="root",
      password="****",
      port = "3306",
      database="nairaland_jobs"                                 
    )
    return  mydatabase

# Function to insert data into the database
def insert_data_into_db(cursor, poster_name, post_count, view_count, time, date, last_poster):
    insert_query = """
    INSERT INTO jobs (poster_name, post_count, view_count, time_posted, date_posted, last_poster_name)
    VALUES (%s, %s, %s, %s, %s, %s)
    """
    cursor.execute(insert_query, (poster_name, post_count, view_count, time, date, last_poster))

# Function to extract data from a single page
def extract_data_from_html(response, cursor):
    soup = BeautifulSoup(response.content, 'html.parser')
    posts = soup.find_all('span', class_='s')  # Adjust the tag and class as per actual HTML structure
    
    # Loop through each post block to extract information
    for post_views_info in posts:
        # Extract poster's name
        poster_name_tag = post_views_info.find('a')  # Assuming the first <a> tag is the poster's name
        poster_name = poster_name_tag.text if poster_name_tag else 'N/A'

        # Extract the number of posts and views
        posts_and_views = post_views_info.find_all('b')
        post_count = posts_and_views[1].text if len(posts_and_views) > 1 else 'N/A'
        view_count = posts_and_views[2].text if len(posts_and_views) > 2 else 'N/A'

        # Extract the time and date of the post
        time = posts_and_views[3].text if len(posts_and_views) > 3 else 'N/A'
        date = posts_and_views[4].text if len(posts_and_views) > 4 else 'N/A'

        # Extract the second poster's name (last poster)
        last_poster_tag = post_views_info.find_all('a')[-1]  # Assuming the last <a> tag is the last poster's name
        last_poster = last_poster_tag.text if last_poster_tag else 'N/A'

        # Insert the data into the database
        insert_data_into_db(cursor, poster_name, post_count, view_count, time, date, last_poster)

# Main function to scrape a single page and insert data into the database
def scrape_single_page(url, cookies, headers):
    connection = connect_to_db()
    cursor = connection.cursor()

    try:
        # Fetch the page using cookies and headers
        response = requests.get(url, cookies=cookies, headers=headers)
        response.raise_for_status()

        # Extract data from the HTML content and insert into DB
        extract_data_from_html(response, cursor)  # Pass the cursor to extract_data_from_html()

        connection.commit()  # Commit the changes after inserting data

    except requests.RequestException as e:
        print(f"Failed to retrieve data from {url}: {e}")
    
    cursor.close()
    connection.close()

# URL of the page to scrape
url = 'https://www.nairaland.com/jobs'

# Start scraping the single page and storing it in the database
scrape_single_page(url, cookies, headers)

# %%
mycursor = mydatabase.cursor()

# Corrected CREATE TABLE statement
mycursor.execute("""
    CREATE TABLE Jobs_2 (
    id INT AUTO_INCREMENT PRIMARY KEY, 
    poster_name VARCHAR(255),
    post_count INT,
    view_count VARCHAR(225),
    time_posted VARCHAR(50),
    date_posted VARCHAR(50),
    last_poster_name VARCHAR(255)
    )
""")

# %%
mycursor = mydatabase.cursor()
mycursor.execute("SHOW TABLES")

for x in mycursor:
  print(x)
# Out:
# ('jobs',)
# ('jobs_2',)

# %%
# PYTHON SCRIPTS PIPELINE FOR THE SECOND TABLE (2) JOBS_2

import mysql.connector
import requests

cookies = {
    'session': '""',
    'ai_user': 'e2Hi55QF1yZg+yBbxztwp6|2024-09-23T04:04:09.869Z',
    'session': '""',
    '_gid': 'GA1.2.927634570.1727849250',
    '__gads': 'ID=b82f70ee813806ec:T=1727064691:RT=1727849696:S=ALNI_MbX4hXYSDlvWE9FqwH08BS8-VgnMA',
    '__gpi': 'UID=00000f096ea6a392:T=1727064691:RT=1727849696:S=ALNI_MYDy964LQKQu4a5evvNhU6RiNAV6w',
    '__eoi': 'ID=9c42286dda43baf5:T=1727064691:RT=1727849696:S=AA-AfjYpPn8xZaYyKA3TAmN8o-44',
    'FCNEC': '%5B%5B%22AKsRol9TcnUvFlUTk2YxxAWVCmcIdyFo_sk4-wyu9PdZa4HUZtqNoi-f4sc1glHbztVAD8XFdexFjlGlK39rbbVbSLzLutPd8qgsNjWLkGFi_iULFKPA3j5OfMMBi-KxR-Lz51PBU415C5_AvZ84EaKE5aGuz_OodQ%3D%3D%22%5D%5D',
    '_gat_gtag_UA_91638_1': '1',
    '_ga_GGM2XGB2C1': 'GS1.1.1727856871.4.1.1727858023.0.0.0',
    '_ga': 'GA1.1.117970615.1727064250',
}

headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'en-US,en;q=0.9',
    'cache-control': 'max-age=0',
    # 'cookie': 'session=""; ai_user=e2Hi55QF1yZg+yBbxztwp6|2024-09-23T04:04:09.869Z; session=""; _gid=GA1.2.927634570.1727849250; __gads=ID=b82f70ee813806ec:T=1727064691:RT=1727849696:S=ALNI_MbX4hXYSDlvWE9FqwH08BS8-VgnMA; __gpi=UID=00000f096ea6a392:T=1727064691:RT=1727849696:S=ALNI_MYDy964LQKQu4a5evvNhU6RiNAV6w; __eoi=ID=9c42286dda43baf5:T=1727064691:RT=1727849696:S=AA-AfjYpPn8xZaYyKA3TAmN8o-44; FCNEC=%5B%5B%22AKsRol9TcnUvFlUTk2YxxAWVCmcIdyFo_sk4-wyu9PdZa4HUZtqNoi-f4sc1glHbztVAD8XFdexFjlGlK39rbbVbSLzLutPd8qgsNjWLkGFi_iULFKPA3j5OfMMBi-KxR-Lz51PBU415C5_AvZ84EaKE5aGuz_OodQ%3D%3D%22%5D%5D; _gat_gtag_UA_91638_1=1; _ga_GGM2XGB2C1=GS1.1.1727856871.4.1.1727858023.0.0.0; _ga=GA1.1.117970615.1727064250',
    'priority': 'u=0, i',
    'referer': 'https://www.nairaland.com/jobs',
    'sec-ch-ua': '"Google Chrome";v="129", "Not=A?Brand";v="8", "Chromium";v="129"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36',
}

# MySQL connection setup
def connect_to_db():
    mydatabase = mysql.connector.connect(  
      host="localhost",
      user="root",
      password="****",
      port = "3306",
      database="nairaland_jobs"                                  
    )
    return  mydatabase

# Function to insert data into the database
def insert_data_into_db(cursor, poster_name, post_count, view_count, time, date, last_poster):
    insert_query = """
    INSERT INTO jobs_2 (poster_name, post_count, view_count, time_posted, date_posted, last_poster_name)
    VALUES (%s, %s, %s, %s, %s, %s)
    """
    cursor.execute(insert_query, (poster_name, post_count, view_count, time, date, last_poster))

# Function to extract data from a single page
def extract_data_from_html(response, cursor):
    soup = BeautifulSoup(response.content, 'html.parser')
    posts = soup.find_all('span', class_='s')  # Adjust the tag and class as per actual HTML structure
    
    # Loop through each post block to extract information
    for post_views_info in posts:
        # Extract poster's name
        poster_name_tag = post_views_info.find('a')  # Assuming the first <a> tag is the poster's name
        poster_name = poster_name_tag.text if poster_name_tag else 'N/A'

        # Extract the number of posts and views
        posts_and_views = post_views_info.find_all('b')
        post_count = posts_and_views[1].text if len(posts_and_views) > 1 else 'N/A'
        view_count = posts_and_views[2].text if len(posts_and_views) > 2 else 'N/A'

        # Extract the time and date of the post
        time = posts_and_views[3].text if len(posts_and_views) > 3 else 'N/A'
        date = posts_and_views[4].text if len(posts_and_views) > 4 else 'N/A'

        # Extract the second poster's name (last poster)
        last_poster_tag = post_views_info.find_all('a')[-1]  # Assuming the last <a> tag is the last poster's name
        last_poster = last_poster_tag.text if last_poster_tag else 'N/A'

        # Insert the data into the database
        insert_data_into_db(cursor, poster_name, post_count, view_count, time, date, last_poster)

# Main function to scrape a single page and insert data into the database
def scrape_single_page(url, cookies, headers):
    connection = connect_to_db()
    cursor = connection.cursor()

    try:
        # Fetch the page using cookies and headers
        response = requests.get(url, cookies=cookies, headers=headers)
        response.raise_for_status()

        # Extract data from the HTML content and insert into DB
        extract_data_from_html(response, cursor)  # Pass the cursor to extract_data_from_html()

        connection.commit()  # Commit the changes after inserting data

    except requests.RequestException as e:
        print(f"Failed to retrieve data from {url}: {e}")
    
    cursor.close()
    connection.close()

# URL of the page to scrape
url = 'https://www.nairaland.com/jobs/1'

# Start scraping the single page and storing it in the database
scrape_single_page(url, cookies, headers)

# %%
# Use the DESC keyword to sort the result in a descending order.
import mysql.connector

mydatabase = mysql.connector.connect(
  host="localhost",
  user="root",
  password="****",
  port = "3306",
  database="nairaland_jobs" 

)

mycursor = mydatabase.cursor()

sql = "SELECT * FROM jobs ORDER BY view_count  DESC"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# (31, 'Romlyn', 1, '94', '6:07pm', 'Oct 02', 'Romlyn')
# (50, 'Danfan', 1, '89', '3:21pm', 'Oct 02', 'Danfan')
# (63, 'bbctech', 20, '864', '1:40pm', 'Oct 02', 'owhede')
# (16, 'MatrixReloaded', 29, '845', '9:50pm', 'Oct 02', 'MatrixReloaded')
# (61, 'desolas', 2, '84', '1:50pm', 'Oct 02', 'bestlary')
# (33, 'okitz4', 19, '7459', '5:44pm', 'Oct 02', 'Esecole232423')
# (46, 'Darudamasta', 2, '74', '3:40pm', 'Oct 02', 'bestlary')
# (59, 'Emmviron', 3, '74', '2:21pm', 'Oct 02', 'xoverx')
# (27, 'fairy88', 3, '74', '8:10pm', 'Oct 02', 'fairy88')
# (56, 'Darudamasta', 3, '71', '2:35pm', 'Oct 02', 'bestlary')
# (28, 'Destiny99', 31, '706', '7:30pm', 'Oct 02', 'oluwaseunayor')
# (10, 'bisiofgod', 76342, '6828461', '11:16pm', 'Oct 02', 'elaino')
# (12, 'PrettyAmazon', 8, '665', '10:58pm', 'Oct 02', 'Zayaki')
# (4, 'PrettyAmazon', 6, '653', '12:19am', 'Zayaki', 'Zayaki')
# (17, 'nlfpmod', 442, '64021', '9:26pm', 'Oct 02', 'Nwuche101')
# (42, 'OptimistSky', 1, '60', '4:08pm', 'Oct 02', 'OptimistSky')
# (40, 'Visec', 2, '60', '4:30pm', 'Oct 02', 'bestlary')
# (32, 'estatemichael', 2, '60', '5:55pm', 'Oct 02', 'bestlary')
# (5, 'PrettyAmazon', 144, '5868', '12:06am', 'Thekingsimon', 'Thekingsimon')
# (49, 'digitaccountant', 1, '50', '3:26pm', 'Oct 02', 'digitaccountant')
# (18, 'PrettyAmazon', 4, '490', '9:10pm', 'Oct 02', 'Danfan')
# (55, 'kennylagos', 1, '48', '2:39pm', 'Oct 02', 'kennylagos')
# (64, 'Gr8Animash', 2, '48', '1:35pm', 'Oct 02', 'bestlary')
# (48, 'DZTech', 8, '451', '3:36pm', 'Oct 02', 'DZTech')
# (30, 'Misterjobs', 2, '45', '6:30pm', 'Oct 02', 'ucheheart')
# (21, 'Besuccesful', 2, '45', '8:52pm', 'Oct 02', 'RealityKings')
# (35, 'michaelodafe', 1, '43', '5:29pm', 'Oct 02', 'michaelodafe')
# (39, 'QuietBoyfriend', 2653094, '4:40pm', 'Oct 02', 'QuietBoyfriend', 'QuietBoyfriend')
# (9, 'Qwinjenna', 2, '394', '11:17pm', 'Oct 02', 'mrjojo')
# (23, 'delelink', 1, '38', '8:48pm', 'Oct 02', 'delelink')
# (36, 'AngelGabbyShara', 1, '38', '5:27pm', 'Oct 02', 'AngelGabbyShara')
# (26, 'dollartree', 1, '38', '8:10pm', 'Oct 02', 'dollartree')
# (2, 'Curdlebug', 6368, '376402', '9:43am', 'Oct 02', 'dharmie13')
# (6, 'PrettyAmazon', 4, '305', '11:52pm', 'Oct 02', 'Danfan')
# (14, 'Ogidanodunayo', 1, '26', '10:34pm', 'Oct 02', 'Ogidanodunayo')
# (8, 'Tohsynetita1', 1, '24', '11:20pm', 'Oct 02', 'Tohsynetita1')
# (65, 'Ebama', 4, '232', '1:34pm', 'Oct 02', 'owhede')
# (44, 'Folabik', 7, '222', '3:59pm', 'Oct 02', 'Folabik')
# (22, 'Rubyjade', 639, '21221', '8:50pm', 'Oct 02', 'Rubyjade')
# (34, 'carolgold', 10, '212', '5:29pm', 'Oct 02', 'xoverx')
# (1, 'LaurelP', 8633, '1864676', '3:09pm', 'Oct 02', 'seundy')
# (43, 'shootsight', 7, '185', '4:00pm', 'Oct 02', 'shootsight')
# (57, 'sathel', 2, '170', '2:22pm', 'Oct 02', 'sathel')
# (41, 'osmerc', 3, '165', '4:21pm', 'Oct 02', 'mrjojo')
# (24, 'PrettyAmazon', 16, '1631', '8:19pm', 'Oct 02', 'Zayaki')
# (37, 'Joseph1505', 6, '161', '5:14pm', 'Oct 02', 'PapaNnamdi')
# (52, 'blossomassor', 1, '158', '3:12pm', 'Oct 02', 'blossomassor')
# (11, 'Anasko', 6, '1578', '11:05pm', 'Oct 02', '042reports')
# (58, 'mercythrone', 2, '152', '2:22pm', 'Oct 02', 'xoverx')
# (54, 'Sam25', 2, '145', '2:45pm', 'Oct 02', 'bestlary')
# (60, 'Davexx', 31110, '1435393', '1:53pm', 'Oct 02', 'bravoluv83')
# (47, 'PrettyAmazon', 1, '139', '3:38pm', 'Oct 02', 'PrettyAmazon')
# (53, 'PrettyAmazon', 10, '1381', '2:50pm', 'Oct 02', 'Carohot')
# (19, 'MouldMade', 8, '137', '9:03pm', 'Oct 02', 'MouldMade')
# (3, 'backT', 529, '136053', '4:45pm', 'Oct 01', 'Joseph1505')
# (38, 'Yoyobravo', 2, '134', '4:45pm', 'Oct 02', 'bestlary')
# (62, 'IncomeTIPS', 3, '128', '1:45pm', 'Oct 02', 'owhede')
# (13, 'irepmyuniben', 10975, '1204971', '10:50pm', 'Oct 02', 'asiwaju60')
# (7, 'Tosade01', 1, '12', '11:37pm', 'Oct 02', 'Tosade01')
# (20, 'LagBlogger', 15, '1048', '8:59pm', 'Oct 02', 'Bizmind95')
# (51, 'Debby1611', 2, '104', '3:15pm', 'Oct 02', 'bestlary')
# (25, 'nifemi25', 7, '103', '8:13pm', 'Oct 02', 'Wealthyonos')
# (45, 'Sam25', 3, '102', '3:45pm', 'Oct 02', 'bestlary')
# (29, 'tohiru2035', 1, '100', '7:11pm', 'Oct 02', 'tohiru2035')
# (15, '042reports', 2113871, '10:32pm', 'Oct 02', '042reports', '042reports')

# %%
# Use the DESC keyword to sort the result in a descending order.
import mysql.connector

mydatabase = mysql.connector.connect(
  host="localhost",
  user="root",
  password="****",
  port = "3306",
  database="nairaland_jobs" 

)

mycursor = mydatabase.cursor()

sql = "SELECT * FROM jobs_2 ORDER BY view_count  DESC"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# (53, 'Jimmyo3', 10480, '994752', '9:55am', 'Oct 01', 'whippersnapper')
# (36, 'Stormyweather', 1, '98', '7:15pm', 'Oct 01', 'Stormyweather')
# (41, 'ned10725', 1, '97', '4:25pm', 'Oct 01', 'ned10725')
# (57, 'Carter90', 1, '87', '9:06am', 'Oct 01', 'Carter90')
# (26, 'Uyoukowise', 1, '85', '5:37am', 'Oct 02', 'Uyoukowise')
# (52, 'sonssyo', 1, '83', '10:02am', 'Oct 01', 'sonssyo')
# (29, 'Ayhisha', 34, '779', '12:19am', 'Oct 02', 'Katsina666')
# (20, 'GAYENI72', 2, '69', '8:20am', 'Oct 02', 'bestlary')
# (7, 'Carter90', 2, '67', '1:25pm', 'Oct 02', 'bestlary')
# (11, 'toobasky', 3, '64', '11:05am', 'Oct 02', 'bestlary')
# (16, 'Roiyke', 2, '64', '9:15am', 'Oct 02', 'bestlary')
# (30, 'Yoyobravo', 6, '570', '11:27pm', 'Oct 01', 'PapaNnamdi')
# (13, 'Rubyjade', 13, '544', '10:56am', 'Oct 02', 'PapaNnamdi')
# (12, 'Craftywriter', 53, '531', '10:59am', 'Oct 02', 'Craftywriter')
# (28, 'NAIJASITE', 2, '53', '5:15am', 'Oct 02', 'NAIJASITE')
# (56, 'ResearchEmp', 13, '517', '9:09am', 'Oct 01', 'ResearchEmp')
# (31, 'Gluckdude20', 14, '480', '11:04pm', 'Oct 01', 'olowobaba')
# (17, 'JobMagnetNg', 3, '467', '8:59am', 'Oct 02', 'nifemi25')
# (40, 'Sejvic', 4, '442', '4:56pm', 'Oct 01', 'Joseph1505')
# (39, 'Redman44', 3, '440', '5:43pm', 'Oct 01', 'Redman44')
# (21, 'Medium2004', 2, '42', '8:00am', 'Oct 02', 'bestlary')
# (22, 'Immigrant2004', 2, '41', '7:55am', 'Oct 02', 'bestlary')
# (1, 'Curdlebug', 6368, '376402', '9:43am', 'Oct 02', 'dharmie13')
# (9, 'mkarnold', 99, '3475', '12:56pm', 'Oct 02', 'mkarnold')
# (15, 'Daninya33', 108, '3437', '9:32am', 'Oct 02', 'Daninya33')
# (47, 'Achigoxtech', 9, '331', '10:52am', 'Oct 01', 'Achigoxtech')
# (18, 'tyj', 3, '319', '8:54am', 'Oct 02', 'tyj')
# (24, 'DesignAce', 100, '3136', '7:03am', 'Oct 02', 'Gr3yCreative')
# (8, 'Kaywhy1', 140, '30810', '1:06pm', 'Oct 02', 'richard870')
# (55, 'OptimistSky', 3, '276', '9:31am', 'Oct 01', 'Mosdiii')
# (44, 'Medium2004', 4, '272', '1:37pm', 'Oct 01', 'Ibkay32')
# (14, 'nicefaze30', 60, '2707', '9:39am', 'Oct 02', 'nicefaze30')
# (27, 'IyaTola', 735, '25396', '5:24am', 'Oct 02', 'IyaTola')
# (49, 'faithobodogulo', 27728, '2490612', '10:21am', 'Oct 01', 'otubobo')
# (45, 'kumari089', 2160, '238497', '12:06pm', 'Oct 01', 'chizobamarvis')
# (6, 'Serah33', 8, '236', '1:26pm', 'Oct 02', 'owhede')
# (59, 'Danfan', 2, '221', '8:08am', 'Oct 01', 'PrettyAmazon')
# (54, 'PrettyAmazon', 19, '2197', '9:34am', 'Oct 01', 'Carohot')
# (10, 'StrangerSal', 335, '20212', '11:19am', 'Oct 02', 'BetterKola')
# (43, 'TIILEAD2WIN', 1, '165', '4:09pm', 'Oct 01', 'TIILEAD2WIN')
# (48, 'Honeygift', 2, '165', '10:29am', 'Oct 01', 'Sunywa')
# (38, 'PrettyAmazon', 2, '163', '6:27pm', 'Oct 01', 'Prettybola')
# (33, 'moneyy88', 1, '158', '8:42pm', 'Oct 01', 'moneyy88')
# (51, 'ThecapitalNGR', 1, '155', '10:04am', 'Oct 01', 'ThecapitalNGR')
# (46, 'Uyoukowise', 1, '146', '11:48am', 'Oct 01', 'Uyoukowise')
# (23, 'MouldMade', 10, '145', '7:11am', 'Oct 02', 'Akinzola')
# (4, 'estatemichael', 2, '138', '1:28pm', 'Oct 02', 'estatemichael')
# (19, 'KAssybabe', 3, '138', '8:51am', 'Oct 02', 'nifemi25')
# (2, 'backT', 529, '136053', '4:45pm', 'Oct 01', 'Joseph1505')
# (32, 'Joseph1505', 4, '130', '10:46pm', 'Oct 01', 'Joseph1505')
# (35, 'Besuccesful', 3, '127', '8:28pm', 'Oct 01', 'Besuccesful')
# (42, 'Fredoh', 22, '1264', '4:17pm', 'Oct 01', 'chizobamarvis')
# (60, 'PrettyAmazon', 6, '1264', '8:05am', 'Oct 01', 'Carohot')
# (5, 'spector15', 141, '12233', '1:26pm', 'Oct 02', '3RNEST')
# (37, 'WorkRemotely', 5, '122', '6:31pm', 'Oct 01', 'PerfectStranger')
# (25, 'Doobie', 4, '117', '6:19am', 'Oct 02', 'Doobie')
# (3, 'Bassmetrics', 33, '1139', '1:30pm', 'Oct 02', 'owhede')
# (58, 'Bizworld1', 1, '108', '8:44am', 'Oct 01', 'Bizworld1')
# (50, 'richmond500', 7, '1006', '10:19am', 'Oct 01', 'Lifemanage')
# (34, 'Besuccesful', 2, '100', '8:29pm', 'Oct 01', 'Besuccesful')
